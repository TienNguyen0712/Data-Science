# %% [markdown]
# # Phần 3 Làm quen với thư viện Mathplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = pd.read_csv("california_cities.csv")
cities.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cities = pd.read_csv("california_cities.csv")
#       2 cities.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
plt.plot();

# %%
x = [1, 2, 3, 4]
y = [10, 8, 6 , 9]
plt.plot(x, y, color = 'red'); # Thêm dấu ";" để xóa bỏ line của Mathplotlib

# %%
plt.style.available # Hiển thị style có sẵn trong Matplotlib
plt.style.use('seaborn-v0_8-whitegrid') # Thay đồi style cho plot

# %% [markdown]
# ### Pylot API và Object-Oriented API
# * Pylot API -> Nhanh chóng
# * OO API -> Phức tạp phải có đủ dữ liễu

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), color = 'blue', linestyle='dashed', label = 'sin(x)');
plt.plot(x, np.cos(x), color= 'red', label = 'cos(x)');
plt.xlabel('Biến x')
plt.ylabel('f(x)')
plt.title('Sin(x) and Cos(x)')
# plt.xlim([0,4])
# plt.ylim([-1.5, 1])
# plt.axis([x min, x max, y min, y max])
plt.axis('equal') # Chỉnh giới hạn cột x và cột y

plt.legend();
# plt.show(); # Chỉ áp dụng khi chạy Matplotlib trên Terminal

# %% [markdown]
# ##### Object-Oriented API

# %%
# 1. Object-Oriented API chuẩn bị dữ liệu
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Điều chỉnh biểu đồ
fig, ax = plt.subplots(figsize=(5,5)) # Điều chỉnh độ rộng 5 chiều cao 5 cho biểu đồ

# 3. Tạo biểu đồ
ax.plot(x, y);

ax.set(title = 'Biều đồ đơn giản', 
      xlabel = 'x-axis',
       ylabel = 'y-axis');

# %% [markdown]
# ## 2. Nhừng loại đồ thị phổ biến trong Matplotlib
# * `Line` : Biểu đồ đường
# * `Scatter` : Đồ thị rời rạc, phân tán
# * `Bar` : Đồ thị dạng cột
# * `Histogram`: Biểu đồ cột
# * `Subplots`: Nhiều đồ thị khác

# %% [markdown]
# #### `Line char` : Biểu đồ đường

# %%
# Tạo mảng 
x  = np.linspace(0, 10, 100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
# OO API plot một line chart
fig, ax = plt.subplots()
ax.plot(x, x**3); # Tạo plot đường với cột x = x, y = x^3

# %% [markdown]
# #### `Scatter` Biểu đồ phân tán

# %%
# Pylot API
plt.scatter(x, np.exp(x)); # y = e^x, x = x

# %%
# Chuẩn bị data mới 
rng = np.random.RandomState(0)

a = rng.randn(100)
b = rng.randn(100)

sizes = 1000 * rng.rand(100)
colors = rng.rand(100)
fig, ax = plt.subplots()

img1 = ax.scatter(a, b, s = sizes, c = colors, cmap = 'viridis', alpha = 0.6);

fig.colorbar(img1) # Tạo phân tán

# %% [markdown]
# #### `Bar Chart` Biểu đồ cột
# * Vertical : Cột ngang
# * Horizontal : Cột dọc

# %%
# Chuẩn bị dữ liệu 
soft_drink_prices = {"Coke" : 10, 
                    "Pepsi" : 12,
                    "Sprite" : 8}
fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax.set(title="Bach Hoa Xanh soft_drink_prices", ylabel = "Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()));

# %% [markdown]
# #### `Histogram` : Thể hiện tần suất dạng cột

# %%
# Chuẩn bị data
np.random.seed(42)
student_height = np.random.normal(170, 10, 250)
student_height[:10], len(student_height)
# Out:
# (array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#         167.65846625, 167.65863043, 185.79212816, 177.67434729,
#         165.30525614, 175.42560044]),
#  250)

# %%
# Pyplot API
plt.hist(student_height, bins=30);

# %% [markdown]
# #### `Subplot` Vễ các Subplots hay nhiều biểu đồ trên một dữ liệu

# %%
# Tạo figure và các subplot
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Vẽ đồ thị vào các subplot
ax[0, 0].plot(x, x/2)
ax[0, 0].plot(x, x + 2)

ax[0, 1].scatter(np.random.rand(10), np.random.rand(10));

ax[1, 0].bar(soft_drink_prices.keys(), soft_drink_prices.values(), color = 'skyblue');

ax[1, 1].hist(student_height, bins=30, edgecolor = 'black');

# %%
# Cách 2: Gán giá trị cho ax1, ax2, ax3, ax4
#Tạo subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

ax1.plot(x, x/2)
ax1.plot(x, x + 2)

ax2.scatter(np.random.rand(10), np.random.rand(10))

ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values(), color='skyblue')

ax4.hist(student_height, bins=30, edgecolor='black')
# Out:
# (array([1., 1., 3., 1., 1., 1., 0., 0., 2., 3., 2., 2., 2., 2., 1., 1., 1.,
#         1., 1., 1., 1., 0., 6., 3., 3., 1., 2., 3., 3., 1.]),
#  array([  2.1675303 ,   8.6986469 ,  15.2297635 ,  21.76088011,
#          28.29199671,  34.82311331,  41.35422992,  47.88534652,
#          54.41646312,  60.94757973,  67.47869633,  74.00981293,
#          80.54092954,  87.07204614,  93.60316274, 100.13427935,
#         106.66539595, 113.19651256, 119.72762916, 126.25874576,
#         132.78986237, 139.32097897, 145.85209557, 152.38321218,
#         158.91432878, 165.44544538, 171.97656199, 178.50767859,
#         185.03879519, 191.5699118 , 198.1010284 ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### Thực hành với các dữ liệu thực tế

# %% [markdown]
# #### Trực quan hóa dữ liệu thành phố Califonia

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset/california_cities.csv')
df.head(5)
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
# Lấy ra các cột để trực quan hóa
lat, long = df['latd'], df['longd']
plt.figure(figsize = (8, 6));
# Plot sử dụng API
plt.scatter(lat, long, c = np.log10(popu), cmap = 'viridis', s = area, linewidth = 0, alpha = 0.7);
plt.colorbar(label = 'log$_(10)$(population)');
plt.clim(3, 7)
plt.xlabel("Kinh độ");
plt.ylabel("Vỹ độ");
plt.title("Phân số kinh độ và vỹ độ thực tế của thành phố Cali")
plt.axis('equal') # Kinh độ và vĩ độ bằng nhau

# Lấy dân cư và Diện tich của Califonia
popu, area = df['population_total'], df['area_total_km2']
# Tạo legend cho kích cỡ của từng thành phố
range = [50, 100, 300, 500]
for i in range:
     plt.scatter([], [], s = i, c='k', alpha = 0.6, label = str(i) + 'km$^2$')
plt.legend(labelspacing = 1, title = 'Diện tích thành phố')
